# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('../../data/Ames_final_df_final.csv', keep_default_na=False)

# %%
df.head()
# Out:
#    LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  YearRemodAdd  \
# 0         65.0     8450            7            5       2003          2003
# 1         80.0     9600            6            8       1976          1976
# 2         68.0    11250            7            5       2001          2002
# 3         60.0     9550            7            5       1915          1970
# 4         84.0    14260            8            5       2000          2000
#
#    MasVnrArea  BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  ...  SaleType_ConLI  \
# 0       196.0         706           0        150  ...           False
# 1         0.0         978           0        284  ...           False
# 2       162.0         486           0        434  ...           False
# 3         0.0         216           0        540  ...           False
# 4       350.0         655           0        490  ...           False
#
#    SaleType_ConLw  SaleType_New  SaleType_Oth  SaleType_WD  \
# ...

# %%
missing = df.isnull().sum()
missing[missing > 0]
# Out:
# Series([], dtype: int64)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1455 entries, 0 to 1454
# Columns: 245 entries, LotFrontage to SaleCondition_Partial
# dtypes: bool(209), float64(3), int64(33)
# memory usage: 706.3 KB

# %%
X = df.drop('SalePrice', axis=1)
y = df['SalePrice']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=101)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
scaler.fit(X_train)
# Out:
# StandardScaler()

# %%
X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
from sklearn.linear_model import ElasticNet

# %%
model = ElasticNet()

# %%
from sklearn.model_selection import GridSearchCV

# %%
parametres = {'alpha': [0.1, 1, 5, 10, 50, 100], 'l1_ratio': [0.1, 0.3, 0.5, 0.8, 0.95, 0.99, 1]}

# %%
grid_model = GridSearchCV(estimator=model, param_grid=parametres, scoring='neg_mean_squared_error', cv=10, verbose=1)

# %%
grid_model.fit(X_train_scaled, y_train)b
# Out:
# Fitting 10 folds for each of 42 candidates, totalling 420 fits
# /home/yerulan/anaconda3/lib/python3.13/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.565e+11, tolerance: 6.960e+08
#   model = cd_fast.enet_coordinate_descent(
# /home/yerulan/anaconda3/lib/python3.13/site-packages/sklearn/linear_model/_coordinate_descent.py:695: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.040e+11, tolerance: 7.002e+08
#   model = cd_fast.enet_coordinate_descent(
# ...

# %%
grid_model.best_estimator_
# Out:
# ElasticNet(alpha=10, l1_ratio=0.99)

# %%
results = pd.DataFrame(grid_model.cv_results_)

# %%
results.head()
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  param_alpha  \
# 0       0.048324      0.006104         0.000781        0.000088          0.1
# 1       0.038992      0.001325         0.000698        0.000084          0.1
# 2       0.053196      0.006558         0.000667        0.000081          0.1
# 3       0.091847      0.004581         0.000656        0.000028          0.1
# 4       0.104466      0.009192         0.000702        0.000113          0.1
#
#    param_l1_ratio                            params  split0_test_score  \
# 0            0.10   {'alpha': 0.1, 'l1_ratio': 0.1}      -6.234012e+08
# 1            0.30   {'alpha': 0.1, 'l1_ratio': 0.3}      -6.230129e+08
# 2            0.50   {'alpha': 0.1, 'l1_ratio': 0.5}      -6.234623e+08
# 3            0.80   {'alpha': 0.1, 'l1_ratio': 0.8}      -6.264734e+08
# 4            0.95  {'alpha': 0.1, 'l1_ratio': 0.95}      -6.297594e+08
#
# ...

# %%
y_predictions = grid_model.predict(X_test_scaled)

# %%
from sklearn.metrics import mean_squared_error

# %%
np.sqrt(mean_squared_error(y_test, y_predictions))
# Out:
# np.float64(23759.580616914267)

# %%
from sklearn.metrics import mean_absolute_error

# %%
mean_absolute_error(y_test, y_predictions)
# Out:
# 17083.18536714998
