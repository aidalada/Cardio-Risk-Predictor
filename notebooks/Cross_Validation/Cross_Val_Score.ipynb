# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('../../data/advertising_dataset_regression.csv')

# %%
df.head()
# Out:
#       TV  radio  newspaper  sales
# 0  112.4    2.6       16.9    8.8
# 1  285.2   26.6       27.9   19.9
# 2  219.6   27.0       17.7   21.6
# 3  179.6   31.9        8.9   19.1
# 4   46.8   36.3       12.1   14.5

# %%
X = df.drop('sales', axis=1)
y = df['sales']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
scaler.fit(X_train)
# Out:
# StandardScaler()

# %%
X_train = scaler.transform(X_train)

# %%
X_test = scaler.transform(X_test)

# %%
from sklearn.linear_model import Ridge

# %%
model = Ridge(alpha = 100)

# %%
from sklearn.model_selection import cross_val_score

# %%
scores = cross_val_score(model, X_train, y_train, scoring='neg_mean_squared_error', cv=5)

# %%
scores
# Out:
# array([-13.00078306,  -9.25913013,  -7.56025917,  -4.27921902,
#         -9.05147232])

# %%
abs(scores.mean())
# Out:
# np.float64(8.630172738245921)

# %%
model = Ridge(alpha = 1)

# %%
scores = cross_val_score(model, X_train, y_train, scoring='neg_mean_squared_error', cv=5)

# %%
scores
# Out:
# array([-4.81915913, -3.99855409, -2.99696285, -2.80680878, -4.9280166 ])

# %%
abs(scores.mean())
# Out:
# np.float64(3.90990028987853)

# %%
model = Ridge(alpha = 0.1)

# %%
scores = cross_val_score(model, X_train, y_train, scoring='neg_mean_squared_error', cv=5)

# %%
scores
# Out:
# array([-4.81142292, -3.98513113, -3.02351711, -2.82903074, -4.90845825])

# %%
abs(scores.mean())
# Out:
# np.float64(3.9115120314896465)

# %%
model = Ridge(alpha=1)

# %%
scores = cross_val_score(model, X_train, y_train, scoring='neg_mean_squared_error', cv=10)

# %%
scores
# Out:
# array([-3.00878657, -6.36200334, -3.870638  , -3.97853597, -2.57137306,
#        -3.23451654, -2.04292505, -3.55326571, -3.64537451, -6.00897301])

# %%
abs(scores.mean())
# Out:
# np.float64(3.827639174196144)

# %%
model = Ridge(alpha=0.1)

# %%
scores = cross_val_score(model, X_train, y_train, scoring='neg_mean_squared_error', cv=10)

# %%
scores
# Out:
# array([-2.99762943, -6.36253955, -3.84050772, -3.98270073, -2.59303016,
#        -3.24553907, -2.06953221, -3.56123678, -3.62309892, -5.99575371])

# %%
abs(scores.mean())
# Out:
# np.float64(3.8271568276270087)

# %%
model.fit(X_train, y_train)
# Out:
# Ridge(alpha=0.1)

# %%
y_final_test_prediciton = model.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error

# %%
mean_squared_error(y_test, y_final_test_prediciton)
# Out:
# 3.703765805312635
